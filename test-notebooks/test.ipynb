# %% [markdown]
# # Initialization

# %%
from google.colab import drive
drive.mount('/gdrive')
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %% [markdown]
# # Boyer Moore Algorithm | Good Suffix heuristic
# **DESCRIPTION**
#
# In computer science, the Boyer–Moore string-search algorithm is an efficient string-searching algorithm that is the standard benchmark for practical string-search literature. It was developed by Robert S. Boyer and J Strother Moore in 1977. The algorithm preprocesses the string being searched for (the pattern), but not the string being searched in (the text). It is thus well-suited for applications in which the pattern is much shorter than the text or where it persists across multiple searches. The Boyer–Moore algorithm uses information gathered during the preprocess step to skip sections of the text, resulting in a lower constant factor than many other string search algorithms. In general, the algorithm runs faster as the pattern length increases. The key features of the algorithm are to match on the tail of the pattern rather than the head, and to skip along the text in jumps of multiple characters rather than searching every single character in the text.
#
# **PERFORMANCE**
#
# The Boyer–Moore algorithm as presented in the original paper has worst-case running time of **`O(n+m)`** only if the pattern does not appear in the text. **`here we gurantee that the patterns always exist, so it never reach the worst case scenario `**

# %%
helper_function_4('/gdrive/My Drive/Genomics/job/data/Output_RYNUM/RYNUM_output_RY_PINK1',1)
# Out:
# RYNUM_RY_TOMM5.txt
# RYNUM_RY_RPS27A.txt
# RYNUM_RY_VDAC1.txt
# RYNUM_RY_TOMM20.txt
# RYNUM_RY_MTERFD1.txt
# RYNUM_RY_HTRA2.txt
# RYNUM_RY_HSP90AA1.txt
# RYNUM_RY_MFN2.txt
# RYNUM_RY_TOMM40.txt
# RYNUM_RY_TOMM7.txt
# RYNUM_RY_ATP13A2.txt
# RYNUM_RY_TOMM22.txt
# RYNUM_RY_TOMM70A.txt
# RYNUM_RY_UBA52.txt
# RYNUM_RY_RHOT1.txt
# RYNUM_RY_UBB.txt
# RYNUM_RY_SNCA.txt
# RYNUM_RY_MFN1.txt
# RYNUM_RY_PINK1.txt
# RYNUM_RY_TOMM6.txt
# RYNUM_RY_PGAM5.txt
# RYNUM_RY_PARKIN.txt
# RYNUM_RY_SQSTM1.txt
# RYNUM_RY_DJ1.txt
# RYNUM_RY_AKT1.txt
# RYNUM_RY_BECN1.txt
# RYNUM_RY_DNM1L.txt
# RYNUM_RY_LRRK2.txt

# %% [markdown]
# ## percentage of each codon

# %%
helper_function_5('/gdrive/My Drive/Genomics/job/data/Output_RYNUM/RYNUM_output_RY_PINK1',1)
# Out:
# RYNUM_RY_TOMM5.txt ----------
# {'1': 16.11071682044003, '2': 10.432931156848829, '3': 9.65223562810504, '4': 12.349183818310859, '5': 11.85237757274663, '6': 10.361958836053939, '7': 11.426543647977288, '8': 17.814052519517386}
#
# RYNUM_RY_RPS27A.txt ----------
# {'1': 15.186028853454822, '2': 11.08580106302202, '3': 9.111617312072893, '4': 12.680334092634777, '5': 12.37661351556568, '6': 10.70615034168565, '7': 12.148823082763856, '8': 16.704631738800305}
#
# RYNUM_RY_VDAC1.txt ----------
# {'1': 16.295892732830897, '2': 11.646841611428917, '3': 9.431278186385786, '4': 12.070583250098368, '5': 11.707376131238838, '6': 10.006356124580043, '7': 12.106903961984322, '8': 16.734768001452828}
#
# RYNUM_RY_TOMM20.txt ----------
# {'1': 14.417602708108939, '2': 11.571010924757655, '3': 10.170795507001078, '4': 12.171103246653331, '5': 12.709647638098168, '6': 10.509309124480689, '7': 12.69426065548546, '8': 15.756270195414679}
#
# RYNUM_RY_MTERFD1.txt ----------
# {'1': 14.652261985145174, '2': 11.51924375422012, '3': 8.683322079675895, '4': 12.032410533423363, '5': 11.667792032410533, '6': 10.965563808237677, '7': 11.951384199864956, '8': 18.528021607022282}
#
# RYNUM_RY_HTRA2.txt ----------
# {'1': 16.329479768786126, '2': 12.644508670520233, '3': 9.393063583815028, '4': 10.69364161849711, '5': 11.488439306358382, '6': 9.609826589595375, '7': 12.5, '8': 17.341040462427745}
#
# RYNUM_RY_HSP90AA1.txt ----------
# {'1': 17.85042452590371, '2': 12.44089684274747, '3': 10.092022980324368, '4': 11.500330469266357, '5': 12.222278712695104, '6': 9.248055315471046, '7': 11.642686460928363, '8': 15.003304692663583}
#
# RYNUM_RY_MFN2.txt ----------
# {'1': 16.281162811628118, '2': 12.006120061200612, '3': 9.68409684096841, '4': 11.619116191161911, '5': 12.060120601206012, '6': 9.765097650976509, '7': 11.718117181171813, '8': 16.86616866168662}
#
# RYNUM_RY_TOMM40.txt ----------
# {'1': 16.626564003849857, '2': 11.790182868142445, '3': 9.33589990375361, '4': 11.405197305101058, '5': 12.223291626564004, '6': 8.806544754571703, '7': 11.838306063522618, '8': 17.974013474494708}
#
# RYNUM_RY_TOMM7.txt ----------
# {'1': 13.30005871990605, '2': 9.89430416911333, '3': 10.041103934233705, '4': 11.597181444509689, '5': 11.215502055196712, '6': 10.510863182618909, '7': 12.977099236641221, '8': 20.46388725778039}
#
# RYNUM_RY_ATP13A2.txt ----------
# {'1': 16.860800369046245, '2': 12.305385768654133, '3': 9.456810056510207, '4': 11.694152923538232, '5': 11.613424057202169, '6': 9.722062045900127, '7': 11.590358666820435, '8': 16.75700611232845}
#
# RYNUM_RY_TOMM22.txt ----------
# {'1': 15.497835497835496, '2': 12.640692640692642, '3': 10.822510822510822, '4': 10.38961038961039, '5': 10.735930735930737, '6': 10.38961038961039, '7': 14.025974025974024, '8': 15.497835497835496}
#
# RYNUM_RY_TOMM70A.txt ----------
# {'1': 14.124113757667489, '2': 11.248307177567115, '3': 10.45168485620967, '4': 11.853740141798772, '5': 11.845773918585198, '6': 11.280172070421413, '7': 12.538835338166177, '8': 16.657372739584165}
#
# RYNUM_RY_UBA52.txt ----------
# {'1': 15.560391730141458, '2': 12.535364526659412, '3': 8.922742110990207, '4': 12.927094668117519, '5': 11.686615886833515, '6': 9.945593035908598, '7': 12.20892274211099, '8': 16.2132752992383}
#
# RYNUM_RY_RHOT1.txt ----------
# {'1': 14.626889892624348, '2': 11.340708084277717, '3': 9.793633191788603, '4': 12.390122521840262, '5': 11.30013793849566, '6': 10.480620993698105, '7': 12.16292970546074, '8': 17.904957671814568}
#
# RYNUM_RY_UBB.txt ----------
# {'1': 20.43010752688172, '2': 11.213517665130567, '3': 13.671274961597543, '4': 9.67741935483871, '5': 10.906298003072196, '6': 6.29800307219662, '7': 13.671274961597543, '8': 14.132104454685098}
#
# RYNUM_RY_SNCA.txt ----------
# {'1': 15.14904793171372, '2': 11.335521996060407, '3': 11.122783978988837, '4': 11.792514773473407, '5': 11.537754432042021, '6': 11.107025607353908, '7': 11.9317137229153, '8': 16.023637557452396}
#
# RYNUM_RY_MFN1.txt ----------
# {'1': 14.483547198577055, '2': 11.79011561428027, '3': 10.29729386354974, '4': 11.898106974971414, '5': 11.421674501334012, '6': 10.9833566255876, '7': 12.158556727226527, '8': 16.967348494473384}
#
# RYNUM_RY_PINK1.txt ----------
# {'1': 17.082087072116984, '2': 11.498836822864739, '3': 9.421734795613162, '4': 11.731472249916916, '5': 13.243602525756065, '6': 9.787304752409439, '7': 10.967098703888336, '8': 16.267863077434363}
#
# RYNUM_RY_TOMM6.txt ----------
# {'1': 11.00244498777506, '2': 12.34718826405868, '3': 9.535452322738386, '4': 14.66992665036675, '5': 11.246943765281173, '6': 8.679706601466993, '7': 12.224938875305623, '8': 20.293398533007334}
#
# RYNUM_RY_PGAM5.txt ----------
# {'1': 15.136226034308779, '2': 11.65489404641776, '3': 9.58627648839556, '4': 12.03329969727548, '5': 11.629667003027246, '6': 10.443995963673057, '7': 12.058526740665993, '8': 17.457114026236127}
#
# RYNUM_RY_PARKIN.txt ----------
# {'1': 16.531440162271803, '2': 10.75050709939148, '3': 12.373225152129818, '4': 12.068965517241379, '5': 11.866125760649087, '6': 9.837728194726166, '7': 11.76470588235294, '8': 14.807302231237324}
#
# RYNUM_RY_SQSTM1.txt ----------
# {'1': 17.070630562393486, '2': 11.797008142397274, '3': 9.401628479454649, '4': 11.711797008142396, '5': 12.005302026131414, '6': 9.392160575648552, '7': 11.901155084264344, '8': 16.720318121567885}
#
# RYNUM_RY_DJ1.txt ----------
# {'1': 14.754716981132077, '2': 11.50943396226415, '3': 10.352201257861635, '4': 12.176100628930818, '5': 11.761006289308176, '6': 10.289308176100628, '7': 12.28930817610063, '8': 16.867924528301888}
#
# RYNUM_RY_AKT1.txt ----------
# {'1': 14.91647855530474, '2': 11.905191873589164, '3': 10.681715575620768, '4': 11.959367945823928, '5': 11.851015801354402, '6': 10.839729119638825, '7': 11.891647855530474, '8': 15.954853273137697}
#
# RYNUM_RY_BECN1.txt ----------
# {'1': 16.962774957698816, '2': 12.119289340101522, '3': 9.898477157360407, '4': 11.315566835871405, '5': 11.696277495769882, '6': 9.285109983079526, '7': 12.267343485617598, '8': 16.455160744500848}
#
# RYNUM_RY_DNM1L.txt ----------
# {'1': 14.91647855530474, '2': 11.905191873589164, '3': 10.681715575620768, '4': 11.959367945823928, '5': 11.851015801354402, '6': 10.839729119638825, '7': 11.891647855530474, '8': 15.954853273137697}
#
# RYNUM_RY_LRRK2.txt ----------
# {'1': 15.077287459486413, '2': 11.439375051940496, '3': 10.818166708219064, '4': 11.852821407795231, '5': 11.00099725754176, '6': 11.354192636915151, '7': 11.68037895786587, '8': 16.776780520236017}
